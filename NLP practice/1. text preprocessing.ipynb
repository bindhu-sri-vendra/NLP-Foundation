# %% [raw]
# Before model can learn from text we need to clean and standardize text
# - tokenization
# - removing stop words
# - stemming
# - Lemmatization
# - text Normalization - Lowercase/ removing - numbers/punctuation/extra space

# %% [raw]
# Preprocessing order is usually this:
#
# lowercase
# ↓
# remove punctuation
# ↓
# tokenize
# ↓
# remove stopwords
# ↓
# stemming/lemmatization

# %%
text = "Hello!!! I am learning NLP in 2026. It's really interesting, isn't it?"

#converting into lower case
text = text.lower()
print(text)
# Out:
# hello!!! i am learning nlp in 2026. it's really interesting, isn't it?

# %%
#removing punctuation

import string
text = text.translate(str.maketrans('','',string.punctuation))
print('text after removing punctuation: ', text)
# Out:
# text after removing punctuation:  hello i am learning nlp in 2026 its really interesting isnt it

# %% [raw]
# str.maketrans(x,y,z)
# x = characters to replace
# y = characters to replace them with
# z = characters to delete
#
# translate applies the whole translation to the text

# %%
#tokenization
import nltk
from nltk.tokenize import word_tokenize

nltk.download('punkt')

tokens = word_tokenize(text)
print('tokens of our text are: ',tokens)
# Out:
# tokens of our text are:  ['hello', 'i', 'am', 'learning', 'nlp', 'in', '2026', 'its', 'really', 'interesting', 'isnt', 'it']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Bindhu_alia\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [raw]
# Why We Download punkt >>> nltk.download('punkt')
#
# This downloads a pretrained tokenizer model used internally by NLTK.
#
# Important point:
# You don't call punkt directly, but word_tokenize() uses it behind the scenes.
#
# So the real process is:
# word_tokenize()
#       ↓
#     uses
#       ↓
# punkt tokenizer model
#
#
# What punkt Actually Does?
#
# punkt is a sentence and word boundary detection model.
# It helps NLTK decide things like:
#
# Where a sentence ends
# Where a word ends
# How punctuation behaves
#
# Example:
# Dr. Smith lives in the U.S.
#
# Without punkt, a tokenizer might think:
#
# Dr
# .
# Smith
#
# But punkt understands abbreviations.
#
# Correct tokenization:
#
# ['Dr.', 'Smith', 'lives', 'in', 'the', 'U.S.']
#
# So punkt helps NLTK split text intelligently.

# %%
#removal of stop words 
from nltk.corpus import stopwords

nltk.download('stopwords')#nltk doesn't automatically download stopwords dataset when we import it so we do it 

stop_words = set(stopwords.words('english'))
filtered_words = [word for word in tokens if word not in stop_words]
print(filtered_words)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Bindhu_alia\AppData\Roaming\nltk_data...
# ['hello', 'learning', 'nlp', '2026', 'really', 'interesting', 'isnt']
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
#stemming >> reducing words to their root form
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

stemmed_words = [stemmer.stem(word) for word in filtered_words]
print(stemmed_words)
# Out:
# ['hello', 'learn', 'nlp', '2026', 'realli', 'interest', 'isnt']

# %%
#lemmatization >> better version of stemming 
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
lem_words = [lemmatizer.lemmatize(word) for word in filtered_words]
print(lem_words)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Bindhu_alia\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ['hello', 'learning', 'nlp', '2026', 'really', 'interesting', 'isnt']
